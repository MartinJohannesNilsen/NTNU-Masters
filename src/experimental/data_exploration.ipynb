# %%
from pathlib import Path
import os
import datetime as dt
import pandas as pd

# %% [markdown]
# ### Set path

# %%
# William Atchison
doc_path = Path(os.path.abspath("")).parents[1] / "schoolshootersinfo" / "William_Atchison" / "data.csv"

# Kimveer_Gill
doc_path = Path(os.path.abspath("")).parents[1] / "schoolshootersinfo" / "Kimveer_Gill" / "data.csv"
assert os.path.isfile(doc_path), "Wrong path"

# %% [markdown]
# ### Read data and append date columns

# %% [markdown]
# NB! Må fikse datetime der month eller day ikke er definert. Nå mistenker jeg at de blir 01.01.xxxx, som er feil. Kan vi få disse til å bli ingenting? Splitte på "-" og sette år, måned, dag hardt kanskje? Drite i datetime objekt en mulighet

# %%
# Read pdf
df = pd.read_csv(doc_path, delimiter="‎ ", engine='python')

# Append year, month and day columns. 
# This method insert None for undefined values
date_dict = { "year": [], "month": [], "day": [] }
for date in df["date"].convert_dtypes():
    year, month, day = [None, None, None] if type(date) == pd._libs.missing.NAType else (date.split("-") + 3 * [None])[:3]
    date_dict["year"].append(year)
    date_dict["month"].append(month)
    date_dict["day"].append(day)
for key in date_dict.keys():
    df[key] = date_dict[key]
df
# Out:
#            date                                               text  year  \
# 0    2005-12-03  Winter - Winter approaches from all  sides. It...  2005
# 1    2005-12-23  Vengeance is coming - It will be a  quiet and ...  2005
# 2    2005-12-27  Lacuna Coil - Listening to Lacuna  Coil. She f...  2005
# 3    2005-12-31  Megadeth - That's a cool name for aband. "Mega...  2005
# 4    2006-01-04  He walks alone - He opened the door,  walked d...  2006
# ..          ...                                                ...   ...
# 110  2006-09-13  - Hey girls, if you're feeling down,  buy a ki...  2006
# 111  2006-09-13  Frezzies - Freezies rock  I'm eatting a purple...  2006
# 112  2006-09-13  It's me :) - German Metal  Yaaaaaaaaaaaaaa  As...  2006
# 113  2006-09-13  Wednessday the 13th - Woke up 30  minutes ago....  2006
# 114  2006-09-13  - Whiskey in the morning,  mmmmmm, mmmmmmmmm, ...  2006
#
#     month day
# 0      12  03
# 1      12  23
# 2      12  27
# 3      12  31
# 4      01  04
# ..    ...  ..
# 110    09  13
# 111    09  13
# 112    09  13
# 113    09  13
# 114    09  13
#
# [115 rows x 5 columns]

# %% [markdown]
# ### Some statistics

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    268 non-null    object
#  1   text    269 non-null    object
#  2   year    268 non-null    object
#  3   month   223 non-null    object
#  4   day     209 non-null    object
# dtypes: object(5)
# memory usage: 10.6+ KB
