# %%
from pathlib import Path
import os
import datetime as dt
import pandas as pd

# %% [markdown]
# ### Set path

# %%
# William Atchison
doc_path = Path(os.path.abspath("")).parents[1] / "schoolshootersinfo" / "William_Atchison" / "data.csv"

# Kimveer_Gill
# doc_path = Path(os.path.abspath("")).parents[1] / "schoolshootersinfo" / "Kimveer_Gill" / "data.csv"

# Sebastian Bosse
# doc_path = Path(os.path.abspath("")).parents[1] / "schoolshootersinfo" / "Sebastian_Bosse" / "data.csv"


assert os.path.isfile(doc_path), "Wrong path"

# %% [markdown]
# ### Read data and append date columns

# %% [markdown]
# NB! Må fikse datetime der month eller day ikke er definert. Nå mistenker jeg at de blir 01.01.xxxx, som er feil. Kan vi få disse til å bli ingenting? Splitte på "-" og sette år, måned, dag hardt kanskje? Drite i datetime objekt en mulighet

# %%
# Read pdf
df = pd.read_csv(doc_path, delimiter="‎ ", engine='python')

# Append year, month and day columns. 
# This method insert None for undefined values
date_dict = { "year": [], "month": [], "day": [] }
for date in df["date"].convert_dtypes():
    year, month, day = [None, None, None] if type(date) == pd._libs.missing.NAType else (date.split("-") + 3 * [None])[:3]
    date_dict["year"].append(year)
    date_dict["month"].append(month)
    date_dict["day"].append(day)
for key in date_dict.keys():
    df[key] = date_dict[key]
df
# Out:
#           date                                               text  year month  \
# 0   2006-08-10  Of all the lives in this world, apparently min...  2006    08
# 1   2006-08-13  Shit! I feel as if I’m about to croak! My hear...  2006    08
# 2   2006-08-19  Imagine you are in your old school, imagine th...  2006    08
# 3   2006-08-25  Soon we are on our way to OP Black Ede, if I c...  2006    08
# 4   2006-09-14  School shooting in Montreal! Quote n24: “. . ....  2006    09
# 5   2006-09-18  We don’t live in a democracy! We are well on o...  2006    09
# 6   2006-09-26  ERIC HARRIS Probably the most reasonable boy t...  2006    09
# 7   2006-10-18  It doesn’t matter what you do in your life, ev...  2006    10
# 8   2006-11-06  Right now I’m holding a 12 Gauge Alarm Patrone...  2006    11
# 9   2006-11-13  Today I passed the point of no return. I shot ...  2006    11
# 10  2006-11-16  I just gave S!lent my G3SAS with all its stuff...  2006    11
# 11  2006-11-17  In 3 days it’s all over. People will be lying ...  2006    11
# 12  2006-11-19  This is the last evening I will ever see. I sh...  2006    11
# 13  2006-11-20                                         That’s it!  2006    11
#
#    day
# 0   10
# 1   13
# 2   19
# 3   25
# 4   14
# 5   18
# 6   26
# 7   18
# 8   06
# 9   13
# 10  16
# 11  17
# 12  19
# 13  20

# %% [markdown]
# ### Some statistics

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    14 non-null     object
#  1   text    14 non-null     object
#  2   year    14 non-null     object
#  3   month   14 non-null     object
#  4   day     14 non-null     object
# dtypes: object(5)
# memory usage: 688.0+ bytes
