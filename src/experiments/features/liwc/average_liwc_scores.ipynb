# %%
import numpy as np
import pandas as pd
from pathlib import Path
import sys
import os

not_preprocessed = Path(os.path.abspath("")).parents[1] / "experiments" / "features" / "liwc" / "not_preprocessed" / "splits"

# %%
shooters_512 = pd.read_csv(not_preprocessed / "csv" / "2022" / "shooters_512")
shooters_256 = pd.read_csv(not_preprocessed / "csv" / "2022" / "shooters_256")
non_shooters_512 = pd.read_csv(not_preprocessed / "csv" / "2022" / "non_shooters_512")
non_shooters_256 = pd.read_csv(not_preprocessed / "csv" / "2022" / "non_shooters_256")

# %%
print(len(shooters_512.columns))
