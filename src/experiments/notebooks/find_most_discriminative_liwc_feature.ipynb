# %%
import os
from pathlib import Path
import pickle

# model_path = Path(os.path.abspath("")).parent / "models" / "saved_models" / "svm" / "liwc" / "2022" / "train_no_stair_twitter" / "sklearn_model.sav"
path = Path(os.path.abspath("")).parent / "models" / "saved_models" / "xgboost" / "liwc" / "2022" / "train_no_stair_twitter" / "sklearn_model.sav"
model = pickle.load(open(path, 'rb'))
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-8-ac0f1e33880f> in <module>
#       5 # model_path = Path(os.path.abspath("")).parent / "models" / "saved_models" / "svm" / "liwc" / "2022" / "train_no_stair_twitter" / "sklearn_model.sav"
#       6 path = Path(os.path.abspath("")).parent / "models" / "saved_models" / "xgboost" / "liwc" / "2022" / "train_no_stair_twitter" / "sklearn_model.sav"
# ----> 7 model = pickle.load(open(path, 'rb'))
#
# ~/.local/lib/python3.6/site-packages/xgboost/core.py in __setstate__(self, state)
#    1450             ptr = (ctypes.c_char * len(buf)).from_buffer(buf)
#    1451             _check_call(
# -> 1452                 _LIB.XGBoosterUnserializeFromBuffer(handle, ptr, length))
#    1453             state['handle'] = handle
#    1454         self.__dict__.update(state)
#
# ...

# %%
import numpy as np

np.argsort(model.feature_importances_)

# Linear kernel sklearn
# np.argsort(np.argsort(model.coef_[1]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-c90720511c4a> in <module>
#       1 import numpy as np
#       2
# ----> 3 np.argsort(clf.coef_[0])
#
# ~/.local/lib/python3.6/site-packages/sklearn/svm/_base.py in coef_(self)
#     499     def coef_(self):
#     500         if self.kernel != 'linear':
# --> 501             raise AttributeError('coef_ is only available when using a '
#     502                                  'linear kernel')
#     503
#
# AttributeError: coef_ is only available when using a linear kernel
