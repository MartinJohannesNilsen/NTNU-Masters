# %%
from sklearn.neighbors import NearestNeighbors
import pandas as pd
from csv import QUOTE_NONE

# %%
df = pd.read_csv("dataset_creation/data/all_labeled_split_512_randy_twitter_sliced.csv", sep="‎", quoting=QUOTE_NONE)

# %%
import sys
import os
sys.path.append("..")

from experiments.utils.word_embeddings import _tokenize_with_preprocessing, get_glove_word_vectors
